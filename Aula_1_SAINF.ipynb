# %%
 # !pip install transformers torch --quiet

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="Shekswess/trlm-135m")
# Out:
# config.json:   0%|          | 0.00/873 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/658 [00:00<?, ?B/s]
# Device set to use cpu

# %%
prompt = "Who are you?"
saida = pipe(prompt, max_new_tokens=50)
print(saida[0]["generated_text"])
# Out:
# Who are you? You are not a man from the sea (since you cannot swim, you are not a man from the sea (since you cannot swim, you are not a man from the sea). Also, you are not a man from the house of the wind

# %%
# !pip install -q -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.9/242.9 kB 5.3 MB/s eta 0:00:00

# %%
from google import genai

API_KEY = "AIzaSyCJbMfLyFECUdZUu3_cGRACznR-jtkvhhQ"

client = genai.Client(api_key = API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Boa tarde, tudo bem?"
)
print(response.text)
# Out:
# Boa tarde! Tudo bem sim, e com você?

# %%
contexto_loja = """
Nome da Loja: EsporteMax

Descrição geral:
A EsporteMax é uma loja especializada em artigos esportivos localizada em São Paulo, voltada para atletas profissionais, amadores e entusiastas do esporte. Nosso objetivo é oferecer produtos de alta qualidade, atendimento personalizado e tecnologia de ponta para potencializar o desempenho dos clientes em qualquer modalidade.

Produtos e categorias:
- Roupas esportivas (camisetas, shorts, calças, agasalhos)
- Calçados para corrida, futebol, basquete, vôlei e treino
- Equipamentos (halteres, colchonetes, bolas, mochilas, garrafas)
- Acessórios (faixas, munhequeiras, bonés, meias técnicas)
- Linha de nutrição esportiva (barras proteicas, isotônicos, suplementos)

Serviços adicionais:
- Entrega expressa para todo o Brasil
- Programa de fidelidade “MaxPoints”
- Consultoria gratuita com especialista esportivo (por agendamento)
- Troca garantida em até 30 dias
- Descontos exclusivos para academias e clubes parceiros

Diferenciais:
- Parceria com marcas como Nike, Adidas, Puma e Under Armour
- Linha sustentável “EcoFit”, feita com tecidos recicláveis
- Atendimento omnichannel (site, aplicativo e loja física)
- Inteligência artificial que recomenda produtos de acordo com o perfil do cliente

Contato:
- Site: www.esportemax.com.br
- WhatsApp: (11) 99999-1234
- E-mail: atendimento@esportemax.com.br
- Endereço: Av. Paulista, 1500 – São Paulo/SP

Missão:
Incentivar a prática esportiva e o bem-estar, oferecendo produtos e experiências que motivem as pessoas a superarem seus limites.
"""

# %%
chat = client.chats.create(
    model="gemini-2.5-flash",
    history=[
        {
            "role": "user",
            "parts": [
                {"text": f"Você é um atendente virtual da loja EsporteMax.
                Use as informações abaixo para responder dúvidas dos clientes:\n{contexto_loja}"}
            ]
        }
    ]
)

# %%
def perguntar(pergunta):
  resposta = chat.send_message(pergunta)
  print("Resposta: ", resposta.text)

pergunta = input("")
perguntar(pergunta)
# Out:
# Boa tarde, que tipo de itens a loja possui?
# Resposta:  Boa tarde! Que bom ter você aqui!
#
# Na EsporteMax, somos especializados em artigos esportivos e temos uma ampla variedade de produtos para todos os tipos de atletas e entusiastas. Nossos itens se dividem nas seguintes categorias:
#
# *   **Roupas esportivas:** Temos camisetas, shorts, calças, agasalhos e muito mais para você se vestir com conforto e estilo.
# *   **Calçados:** Contamos com tênis específicos para diversas modalidades, como corrida, futebol, basquete, vôlei e treino.
# *   **Equipamentos:** Oferecemos halteres, colchonetes, bolas, mochilas, garrafas e diversos outros equipamentos para seu treino ou esporte.
# *   **Acessórios:** Você encontra faixas, munhequeiras, bonés, meias técnicas e uma série de itens complementares.
# *   **Linha de nutrição esportiva:** Dispomos de barras proteicas, isotônicos e suplementos para auxiliar na sua performance e recuperação.
#
# ...
